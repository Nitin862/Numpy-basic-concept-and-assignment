# %%
'''Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
Matplotlib.'''
# Out:
# 'Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of\nMatplotlib.'

# %%
'''Matplotlib is a visualization tool in python which is used for data representation in vrious representation of chart and
helps in drawing seful insight. The five plots that can be used to plot data are:
1.Scatter
2.Line
3.Pie
4.Bar
5.Histogram'''
# Out:
# 'Matplotlib is a visualization tool in python which is used for data representation in vrious representation of chart and\nhelps in drawing seful insight. The five plots that can be used to plot data are:\n1.Scatter\n2.Line\n3.Pie\n4.Bar\n5.Histogram'

# %%
'''Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))'''
# Out:
# 'Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data\nplot a scatter plot.\nimport numpy as np\nnp.random.seed(3)\nx = 3 + np.random.normal(0, 2, 50)\ny = 3 + np.random.normal(0, 2, len(x))'

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.xlabel("This is x axis")
plt.ylabel("This is y axis")
plt.title('This is sample data plot')
# Out:
# Text(0.5, 1.0, 'This is sample data plot')

# %%
plt.scatter(x,y)

# %%
'''Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:
import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])'''
# Out:
# 'Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.\nUse the following data:\nimport numpy as np\nFor line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])\nFor line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])\nFor line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])\nFor line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])'

# %%
'''The subplot() function in Matplotlib is used to create multiple plots within a single figure. It allows you to arrange plots
in a grid of rows and columns,
specifying the location of each subplot using its row, column, and index.'''
# Out:
# 'The subplot() function in Matplotlib is used to create multiple plots within a single figure. It allows you to arrange plots\nin a grid of rows and columns,\nspecifying the location of each subplot using its row, column, and index.'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for four lines
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Creating subplots
plt.figure(figsize=(10, 8))

# Subplot 1
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, subplot 1
plt.plot(x1, y1)
plt.title('Line 1')

# Subplot 2
plt.subplot(2, 2, 2)  # 2 rows, 2 columns, subplot 2
plt.plot(x2, y2)
plt.title('Line 2')

# Subplot 3
plt.subplot(2, 2, 3)  # 2 rows, 2 columns, subplot 3
plt.plot(x3, y3)
plt.title('Line 3')

# Subplot 4
plt.subplot(2, 2, 4)  # 2 rows, 2 columns, subplot 4
plt.plot(x4, y4)
plt.title('Line 4')

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %%
'''Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])'''
# Out:
# 'Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.\nimport numpy as np\ncompany = np.array(["Apple", "Microsoft", "Google", "AMD"])\nprofit = np.array([3000, 8000, 1000, 10000])'

# %%
'''Bar graph is rectangular representation of the data.The length or height of each bar represents the value associated with a particular category.'''
# Out:
# 'Bar graph is rectangular representation of the data.The length or height of each bar represents the value associated with a particular category.'

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Creating a bar plot
plt.figure(figsize=(8, 6))
plt.bar(company, profit, color='red')
plt.title('Bar Plot - Company Profits')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.grid(axis='y')  # Show gridlines on y-axis
plt.show()

# %%
'''Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)'''
# Out:
# 'Q5: What is a box plot? Why is it used? Using the following data plot a box plot.\nbox1 = np.random.normal(100, 10, 200)\nbox2 = np.random.normal(90, 20, 200)'

# %%
# Generating data for box plots
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Creating a box plot
plt.figure(figsize=(8, 6))
plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'])
plt.title('Box Plot - Comparison of Box 1 and Box 2')
plt.xlabel('Box')
plt.ylabel('Values')
plt.grid(axis='y')  # Show gridlines on y-axis
plt.show()

# %%
'''A box plot, also known as a box-and-whisker plot, is a statistical visualization that displays the distribution of a dataset along 
with its key statistical measures. It presents a visual summary of the minimum, first quartile (Q1), 
median (second quartile, Q2), third quartile (Q3), and maximum of a dataset. '''
# Out:
# 'A box plot, also known as a box-and-whisker plot, is a statistical visualization that displays the distribution of a dataset along \nwith its key statistical measures. It presents a visual summary of the minimum, first quartile (Q1), \nmedian (second quartile, Q2), third quartile (Q3), and maximum of a dataset. '
